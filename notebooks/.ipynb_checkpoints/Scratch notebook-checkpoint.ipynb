# %%
import camelot

# %%
f = '../raw_pdf/54R_1996.pdf'

# %%
tables = camelot.read_pdf(f)

# %%
tables[0].df
# Out:
#                                                   0   \
# 0                                              เดือน
# 1
# 2
# 3  มกราคม\nกุมภาพันธ\nม\nีนาคม\nเมษายน\nพฤษภาคม\...
# 4                                       ค\nามาตรฐาน
#
#                                                1   \
# 0                ก\nาซซัลเฟอรไดออกไซด  ( SO2 )
# 1                คาเฉลี\n่ย 1 ชั\n่วโมง  ( ppb )
# 2                                     ค\nาสูงสุด
# 3  #\n#\n#\n#\n#\n#\n#\n#\n73.0\n92.0\n71.9\n86.9
# 4                                             300
#
#                                            2   \
# 0
# 1
# 2                              ค\nาต่\nําสุด
# 3  #\n#\n#\n#\n#\n#\n#\n#\n0.0\n1.0\n5.4\n6.4
# 4
#
#                                                   3   \
# 0
# 1
# 2                                     ครั\n้ง > std.
# 3  #\n#\n#\n#\n#\n#\n#\n#\n0/380*\n0/620\n0/482*\...
# 4
#
#                                                4   \
# 0
# 1                           คาเฉลี\n่ย\nรายเดือน
# 2
# 3  #\n#\n#\n#\n#\n#\n#\n#\n15.2\n22.9\n28.2\n30.8
# 4                                               -
#
#                                                   5   \
# 0                   ก\nาซไนโตรเจนไดออกไซด  ( NO2 )
# 1                   คาเฉลี\n่ย 1 ชั\n่วโมง  ( ppb )
# 2                                        ค\nาสูงสุด
# 3  #\n#\n#\n#\n#\n#\n#\n#\n115.0\n150.0\n98.0\n100.0
# 4                                                170
#
#                                                6   \
# 0
# 1
# 2                                  ค\nาต่\nําสุด
# 3  #\n#\n#\n#\n#\n#\n#\n#\n11.0\n15.0\n16.0\n22.0
# 4
#
#                                                   7   \
# 0
# 1
# 2                                     ครั\n้ง > std.
# 3  #\n#\n#\n#\n#\n#\n#\n#\n0/562\n0/579\n0/658\n0...
# 4
#
#                                                8   \
# 0
# 1                           คาเฉลี\n่ย\nรายเดือน
# 2
# 3  #\n#\n#\n#\n#\n#\n#\n#\n38.6\n50.9\n52.7\n61.5
# 4                                               -
#
#                                                9   ...  \
# 0                  ก\nาซคารบอนมอนอกไซด  ( CO )  ...
# 1                คาเฉลี\n่ย 1 ชั\n่วโมง  ( ppm )  ...
# 2                                     ค\nาสูงสุด  ...
# 3  #\n#\n#\n#\n#\n#\n#\n#\n19.1\n10.7\n11.7\n10.6  ...
# 4                                              30  ...
#
#                                                   11  \
# 0
# 1
# 2                                     ครั\n้ง > std.
# 3  #\n#\n#\n#\n#\n#\n#\n#\n0/635\n0/694\n0/631\n0...
# 4
#
#                                            12  \
# 0
# 1                       คาเฉลี\n่ย\nรายเดือน
# 2
# 3  #\n#\n#\n#\n#\n#\n#\n#\n4.1\n3.8\n3.7\n3.6
# 4                                           -
#
#                                                13  \
# 0                             ก\nาซโอโซน  ( O3 )
# 1                คาเฉลี\n่ย 1 ชั\n่วโมง  ( ppb )
# 2                                     ค\nาสูงสุด
# 3  #\n#\n#\n#\n#\n#\n#\n#\n30.0\n18.0\n21.0\n30.0
# 4                                             100
#
#                                            14  \
# 0
# 1
# 2                              ค\nาต่\nําสุด
# 3  #\n#\n#\n#\n#\n#\n#\n#\n0.0\n0.0\n0.0\n0.0
# 4
#
#                                                   15  \
# 0
# 1
# 2                                     ครั\n้ง > std.
# 3  #\n#\n#\n#\n#\n#\n#\n#\n0/625\n0/334**\n0/630\...
# 4
#
#                                            16  \
# 0
# 1                       คาเฉลี\n่ย\nรายเดือน
# 2
# 3  #\n#\n#\n#\n#\n#\n#\n#\n1.4\n2.8\n3.4\n4.8
# 4                                           -
#
#                                                   17  \
# 0                ฝุ\nนขนาดเล็กกวา 10 ไมครอน (PM10)
# 1                คาเฉลี\n่ย 24 ชั\n่วโมง  ( ug/m3 )
# 2                                        ค\nาสูงสุด
# 3  #\n#\n#\n#\n#\n#\n#\n#\n285.7\n313.4\n290.5\n3...
# 4                                                120
#
#                                                   18  \
# 0
# 1
# 2                                     ค\nาต่\nําสุด
# 3  #\n#\n#\n#\n#\n#\n#\n#\n81.5\n117.9\n123.4\n137.8
# 4
#
#                                                   19  \
# 0
# 1
# 2                                     ครั\n้ง > std.
# 3  #\n#\n#\n#\n#\n#\n#\n#\n21/30\n30/31\n30/30\n3...
# 4
#
#                                                   20
# 0
# 1                              คาเฉลี\n่ย\nรายเดือน
# 2
# 3  #\n#\n#\n#\n#\n#\n#\n#\n163.2\n198.3\n205.8\n2...
# 4                                                  -
#
# [5 rows x 21 columns]

# %%
# %matplotlib inline
import pdfplumber

# %%
from pprint import pprint

# %%
f = '../raw_pdf/54R_1996.pdf'
pdf = pdfplumber.open(f)
first_page = pdf.pages[0]
im = first_page.to_image()
words = first_page.extract_words(x_tolerance=3, y_tolerance=25)
im.draw_rects(words)

# %%
im = first_page.to_image()

im.draw_hlines([100,200,300,400])

# %%
def clean_thai(s):
    sub = {
        '\uf702': 'ี',
        '\uf70c': '๊',
        '\uf70e': '์',
        '\uf705': '่',
        '\uf70a': '่'
    }
    tmp = s
    for k, v in sub.items():
        tmp = tmp.replace(k, v)
    return tmp

# %%
type(words[0])
# Out:
# dict

# %%
for word in words:
    word['text'] = clean_thai(word['text'])

gas_line = [word['bottom']
            for word in words if word['text'].startswith('ก๊าซ')]


def unique(values):
    tmp = []
    s = set()
    for v in values:
        if v not in s:
            tmp.append(v)
        s.add(v)
    return tmp


col_map = ['high', 'low', 'n_over', 'monthly_avg']
months = [
    'มกราคม',
    'กุมภาพันธ์', 
    'มีนาคม', 
    'เมษายน', 
    'พฤษภาคม', 
    'มิถุนายน', 
    'กรกฎาคม', 
    'สิงหาคม', 
    'กันยายน', 
    'ตุลาคม', 
    'พฤศจิกายน', 
    'ธันวาคม']

months_set = set(months)

months_line = [word['bottom'] for word in words if word['text'] in months_set and word['x0'] < first_page.width/2]

print(len(months_line))
lines = unique([word['bottom'] for word in words])


im = first_page.to_image()

im.draw_hlines(months_line)
# Out:
# 12

# %%
def group_by(values, key):
    tmp = {}
    for v in values:
        k = key(v)
        if k not in tmp:
            tmp[k] = []
        tmp[k].append(v)
    return tmp

# %%
word_by_line = group_by(words, lambda x: x['bottom'])
word_by_line
# Out:
# {Decimal('43.510'): [{'x0': Decimal('248.271'),
#    'x1': Decimal('473.925'),
#    'top': Decimal('13.694'),
#    'bottom': Decimal('43.510'),
#    'text': 'คุณภาพอากาศบริเวณเคหะชุมชนดินแดง'},
#   {'x0': Decimal('480.951'),
#    'x1': Decimal('492.677'),
#    'top': Decimal('13.694'),
#    'bottom': Decimal('43.510'),
#    'text': 'ถ.'},
#   {'x0': Decimal('496.191'),
#    'x1': Decimal('536.924'),
#    'top': Decimal('13.694'),
#    'bottom': Decimal('43.510'),
#    'text': 'ดินแดง'},
#   {'x0': Decimal('543.950'),
#    'x1': Decimal('553.221'),
#    'top': Decimal('13.694'),
#    'bottom': Decimal('43.510'),
#    'text': 'ปี'},
#   {'x0': Decimal('560.147'),
#    'x1': Decimal('587.740'),
#    'top': Decimal('13.694'),
#    'bottom': Decimal('43.510'),
#    'text': '2539'}],
#  Decimal('84.554'): [{'x0': Decimal('98.751'),
#    'x1': Decimal('177.470'),
#    'top': Decimal('66.904'),
#    'bottom': Decimal('84.554'),
#    'text': 'ก๊าซซัลเฟอร์ไดออกไซด์'},
#   {'x0': Decimal('181.579'),
#    'x1': Decimal('184.298'),
#    'top': Decimal('66.904'),
#    'bottom': Decimal('84.554'),
#    'text': '('},
#   {'x0': Decimal('186.352'),
#    'x1': Decimal('197.229'),
#    'top': Decimal('66.904'),
#    'bottom': Decimal('84.554'),
#    'text': 'SO'},
#   {'x0': Decimal('202.070'),
#    'x1': Decimal('204.789'),
#    'top': Decimal('66.904'),
#    'bottom': Decimal('84.554'),
#    'text': ')'},
#   {'x0': Decimal('242.631'),
#    'x1': Decimal('327.950'),
#    'top': Decimal('66.904'),
#    'bottom': Decimal('84.554'),
#    'text': 'ก๊าซไนโตรเจนไดออกไซด์'},
#   {'x0': Decimal('332.059'),
#    'x1': Decimal('334.778'),
#    'top': Decimal('66.904'),
#    'bottom': Decimal('84.554'),
#    'text': '('},
#   {'x0': Decimal('336.832'),
#    'x1': Decimal('349.069'),
#    'top': Decimal('66.904'),
#    'bottom': Decimal('84.554'),
#    'text': 'NO'},
#   {'x0': Decimal('353.870'),
#    'x1': Decimal('356.589'),
#    'top': Decimal('66.904'),
#    'bottom': Decimal('84.554'),
#    'text': ')'},
#   {'x0': Decimal('565.791'),
#    'x1': Decimal('602.000'),
#    'top': Decimal('66.904'),
#    'bottom': Decimal('84.554'),
#    'text': 'ก๊าซโอโซน'},
#   {'x0': Decimal('606.138'),
#    'x1': Decimal('608.858'),
#    'top': Decimal('66.904'),
#    'bottom': Decimal('84.554'),
#    'text': '('},
#   {'x0': Decimal('610.912'),
#    'x1': Decimal('617.253'),
#    'top': Decimal('66.904'),
#    'bottom': Decimal('84.554'),
#    'text': 'O'},
#   {'x0': Decimal('622.070'),
#    'x1': Decimal('624.789'),
#    'top': Decimal('66.904'),
#    'bottom': Decimal('84.554'),
#    'text': ')'},
#   {'x0': Decimal('682.671'),
#    'x1': Decimal('736.929'),
#    'top': Decimal('66.904'),
#    'bottom': Decimal('84.554'),
#    'text': 'ฝุ่นขนาดเล็กกว่า'},
#   {'x0': Decimal('738.951'),
#    'x1': Decimal('747.108'),
#    'top': Decimal('66.904'),
#    'bottom': Decimal('84.554'),
#    'text': '10'},
#   {'x0': Decimal('749.151'),
#    'x1': Decimal('777.808'),
#    'top': Decimal('66.904'),
#    'bottom': Decimal('84.554'),
#    'text': 'ไมครอน'},
#   {'x0': Decimal('779.871'),
#    'x1': Decimal('795.301'),
#    'top': Decimal('66.904'),
#    'bottom': Decimal('84.554'),
#    'text': '(PM'},
#   {'x0': Decimal('800.871'),
#    'x1': Decimal('803.590'),
#    'top': Decimal('66.904'),
#    'bottom': Decimal('84.554'),
#    'text': ')'}],
#  Decimal('84.794'): [{'x0': Decimal('393.469'),
#    'x1': Decimal('475.548'),
#    'top': Decimal('67.144'),
#    'bottom': Decimal('84.794'),
#    'text': 'ก๊าซคาร์บอนมอนอกไซด์'},
#   {'x0': Decimal('479.650'),
#    'x1': Decimal('482.369'),
#    'top': Decimal('67.144'),
#    'bottom': Decimal('84.794'),
#    'text': '('},
#   {'x0': Decimal('484.419'),
#    'x1': Decimal('496.656'),
#    'top': Decimal('67.144'),
#    'bottom': Decimal('84.794'),
#    'text': 'CO'},
#   {'x0': Decimal('498.706'),
#    'x1': Decimal('501.425'),
#    'top': Decimal('67.144'),
#    'bottom': Decimal('84.794'),
#    'text': ')'}],
#  Decimal('85.979'): [{'x0': Decimal('197.271'),
#    'x1': Decimal('200.003'),
#    'top': Decimal('74.155'),
#    'bottom': Decimal('85.979'),
#    'text': '2'},
#   {'x0': Decimal('349.071'),
#    'x1': Decimal('351.803'),
#    'top': Decimal('74.155'),
#    'bottom': Decimal('85.979'),
#    'text': '2'},
#   {'x0': Decimal('617.271'),
#    'x1': Decimal('620.003'),
#    'top': Decimal('74.155'),
#    'bottom': Decimal('85.979'),
#    'text': '3'},
#   {'x0': Decimal('795.351'),
#    'x1': Decimal('800.815'),
#    'top': Decimal('74.155'),
#    'bottom': Decimal('85.979'),
#    'text': '10'}],
#  Decimal('108.882'): [{'x0': Decimal('37.431'),
#    'x1': Decimal('59.186'),
#    'top': Decimal('87.120'),
#    'bottom': Decimal('108.882'),
#    'text': 'เดือน'}],
#  Decimal('108.194'): [{'x0': Decimal('91.910'),
#    'x1': Decimal('117.123'),
#    'top': Decimal('90.544'),
#    'bottom': Decimal('108.194'),
#    'text': 'ค่าเฉลี่ย'},
#   {'x0': Decimal('119.149'),
#    'x1': Decimal('123.228'),
#    'top': Decimal('90.544'),
#    'bottom': Decimal('108.194'),
#    'text': '1'},
#   {'x0': Decimal('125.270'),
#    'x1': Decimal('147.256'),
#    'top': Decimal('90.544'),
#    'bottom': Decimal('108.194'),
#    'text': 'ชั่วโมง'},
#   {'x0': Decimal('151.338'),
#    'x1': Decimal('154.057'),
#    'top': Decimal('90.544'),
#    'bottom': Decimal('108.194'),
#    'text': '('},
#   {'x0': Decimal('156.112'),
#    'x1': Decimal('169.720'),
#    'top': Decimal('90.544'),
#    'bottom': Decimal('108.194'),
#    'text': 'ppb'},
#   {'x0': Decimal('171.824'),
#    'x1': Decimal('174.543'),
#    'top': Decimal('90.544'),
#    'bottom': Decimal('108.194'),
#    'text': ')'},
#   {'x0': Decimal('194.631'),
#    'x1': Decimal('219.844'),
#    'top': Decimal('90.544'),
#    'bottom': Decimal('108.194'),
#    'text': 'ค่าเฉลี่ย'},
#   {'x0': Decimal('239.749'),
#    'x1': Decimal('264.963'),
#    'top': Decimal('90.544'),
#    'bottom': Decimal('108.194'),
#    'text': 'ค่าเฉลี่ย'},
#   {'x0': Decimal('266.988'),
#    'x1': Decimal('271.067'),
#    'top': Decimal('90.544'),
#    'bottom': Decimal('108.194'),
#    'text': '1'},
#   {'x0': Decimal('273.109'),
#    'x1': Decimal('295.095'),
#    'top': Decimal('90.544'),
#    'bottom': Decimal('108.194'),
#    'text': 'ชั่วโมง'},
#   {'x0': Decimal('299.177'),
#    'x1': Decimal('301.897'),
#    'top': Decimal('90.544'),
#    'bottom': Decimal('108.194'),
#    'text': '('},
#   {'x0': Decimal('303.951'),
#    'x1': Decimal('317.559'),
#    'top': Decimal('90.544'),
#    'bottom': Decimal('108.194'),
#    'text': 'ppb'},
#   {'x0': Decimal('319.663'),
#    'x1': Decimal('322.382'),
#    'top': Decimal('90.544'),
#    'bottom': Decimal('108.194'),
#    'text': ')'},
#   {'x0': Decimal('342.468'),
#    'x1': Decimal('367.683'),
#    'top': Decimal('90.544'),
#    'bottom': Decimal('108.194'),
#    'text': 'ค่าเฉลี่ย'},
#   {'x0': Decimal('386.510'),
#    'x1': Decimal('411.723'),
#    'top': Decimal('90.544'),
#    'bottom': Decimal('108.194'),
#    'text': 'ค่าเฉลี่ย'},
#   {'x0': Decimal('413.748'),
#    'x1': Decimal('417.827'),
#    'top': Decimal('90.544'),
#    'bottom': Decimal('108.194'),
#    'text': '1'},
#   {'x0': Decimal('419.869'),
#    'x1': Decimal('441.855'),
#    'top': Decimal('90.544'),
#    'bottom': Decimal('108.194'),
#    'text': 'ชั่วโมง'},
#   {'x0': Decimal('445.938'),
#    'x1': Decimal('448.657'),
#    'top': Decimal('90.544'),
#    'bottom': Decimal('108.194'),
#    'text': '('},
#   {'x0': Decimal('450.711'),
#    'x1': Decimal('466.581'),
#    'top': Decimal('90.544'),
#    'bottom': Decimal('108.194'),
#    'text': 'ppm'},
#   {'x0': Decimal('468.708'),
#    'x1': Decimal('471.428'),
#    'top': Decimal('90.544'),
#    'bottom': Decimal('108.194'),
#    'text': ')'},
#   {'x0': Decimal('490.308'),
#    'x1': Decimal('515.522'),
#    'top': Decimal('90.544'),
#    'bottom': Decimal('108.194'),
#    'text': 'ค่าเฉลี่ย'},
#   {'x0': Decimal('535.430'),
#    'x1': Decimal('560.643'),
#    'top': Decimal('90.544'),
#    'bottom': Decimal('108.194'),
#    'text': 'ค่าเฉลี่ย'},
#   {'x0': Decimal('562.669'),
#    'x1': Decimal('566.748'),
#    'top': Decimal('90.544'),
#    'bottom': Decimal('108.194'),
#    'text': '1'},
#   {'x0': Decimal('568.790'),
#    'x1': Decimal('590.780'),
#    'top': Decimal('90.544'),
#    'bottom': Decimal('108.194'),
#    'text': 'ชั่วโมง'},
#   {'x0': Decimal('594.858'),
#    'x1': Decimal('597.578'),
#    'top': Decimal('90.544'),
#    'bottom': Decimal('108.194'),
#    'text': '('},
#   {'x0': Decimal('599.632'),
#    'x1': Decimal('613.240'),
#    'top': Decimal('90.544'),
#    'bottom': Decimal('108.194'),
#    'text': 'ppb'},
#   {'x0': Decimal('615.344'),
#    'x1': Decimal('618.063'),
#    'top': Decimal('90.544'),
#    'bottom': Decimal('108.194'),
#    'text': ')'},
#   {'x0': Decimal('638.147'),
#    'x1': Decimal('663.361'),
#    'top': Decimal('90.544'),
#    'bottom': Decimal('108.194'),
#    'text': 'ค่าเฉลี่ย'},
#   {'x0': Decimal('785.990'),
#    'x1': Decimal('811.204'),
#    'top': Decimal('90.544'),
#    'bottom': Decimal('108.194'),
#    'text': 'ค่าเฉลี่ย'}],
#  Decimal('106.994'): [{'x0': Decimal('677.868'),
#    'x1': Decimal('703.081'),
#    'top': Decimal('89.344'),
#    'bottom': Decimal('106.994'),
#    'text': 'ค่าเฉลี่ย'},
#   {'x0': Decimal('705.107'),
#    'x1': Decimal('713.265'),
#    'top': Decimal('89.344'),
#    'bottom': Decimal('106.994'),
#    'text': '24'},
#   {'x0': Decimal('715.308'),
#    'x1': Decimal('737.294'),
#    'top': Decimal('89.344'),
#    'bottom': Decimal('106.994'),
#    'text': 'ชั่วโมง'},
#   {'x0': Decimal('741.376'),
#    'x1': Decimal('744.096'),
#    'top': Decimal('89.344'),
#    'bottom': Decimal('106.994'),
#    'text': '('},
#   {'x0': Decimal('746.156'),
#    'x1': Decimal('766.643'),
#    'top': Decimal('88.075'),
#    'bottom': Decimal('106.994'),
#    'text': 'ug/m3'},
#   {'x0': Decimal('768.710'),
#    'x1': Decimal('771.429'),
#    'top': Decimal('89.344'),
#    'bottom': Decimal('106.994'),
#    'text': ')'}],
#  Decimal('131.015'): [{'x0': Decimal('84.471'),
#    'x1': Decimal('108.190'),
#    'top': Decimal('116.107'),
#    'bottom': Decimal('131.015'),
#    'text': 'ค่าสูงสุด'},
#   {'x0': Decimal('121.661'),
#    'x1': Decimal('144.909'),
#    'top': Decimal('116.107'),
#    'bottom': Decimal('131.015'),
#    'text': 'ค่าต่ําสุด'},
#   {'x0': Decimal('155.739'),
#    'x1': Decimal('166.921'),
#    'top': Decimal('116.107'),
#    'bottom': Decimal('131.015'),
#    'text': 'ครั้ง'},
#   {'x0': Decimal('168.606'),
#    'x1': Decimal('172.531'),
#    'top': Decimal('116.107'),
#    'bottom': Decimal('131.015'),
#    'text': '>'},
#   {'x0': Decimal('174.213'),
#    'x1': Decimal('184.700'),
#    'top': Decimal('116.107'),
#    'bottom': Decimal('131.015'),
#    'text': 'std.'},
#   {'x0': Decimal('232.311'),
#    'x1': Decimal('256.030'),
#    'top': Decimal('116.107'),
#    'bottom': Decimal('131.015'),
#    'text': 'ค่าสูงสุด'},
#   {'x0': Decimal('269.501'),
#    'x1': Decimal('292.750'),
#    'top': Decimal('116.107'),
#    'bottom': Decimal('131.015'),
#    'text': 'ค่าต่ําสุด'},
#   {'x0': Decimal('303.580'),
#    'x1': Decimal('314.761'),
#    'top': Decimal('116.107'),
#    'bottom': Decimal('131.015'),
#    'text': 'ครั้ง'},
#   {'x0': Decimal('316.446'),
#    'x1': Decimal('320.372'),
#    'top': Decimal('116.107'),
#    'bottom': Decimal('131.015'),
#    'text': '>'},
#   {'x0': Decimal('322.054'),
#    'x1': Decimal('332.541'),
#    'top': Decimal('116.107'),
#    'bottom': Decimal('131.015'),
#    'text': 'std.'},
#   {'x0': Decimal('380.151'),
#    'x1': Decimal('403.870'),
#    'top': Decimal('116.107'),
#    'bottom': Decimal('131.015'),
#    'text': 'ค่าสูงสุด'},
#   {'x0': Decimal('417.341'),
#    'x1': Decimal('440.590'),
#    'top': Decimal('116.107'),
#    'bottom': Decimal('131.015'),
#    'text': 'ค่าต่ําสุด'},
#   {'x0': Decimal('451.420'),
#    'x1': Decimal('462.601'),
#    'top': Decimal('116.107'),
#    'bottom': Decimal('131.015'),
#    'text': 'ครั้ง'},
#   {'x0': Decimal('464.286'),
#    'x1': Decimal('468.212'),
#    'top': Decimal('116.107'),
#    'bottom': Decimal('131.015'),
#    'text': '>'},
#   {'x0': Decimal('469.894'),
#    'x1': Decimal('480.381'),
#    'top': Decimal('116.107'),
#    'bottom': Decimal('131.015'),
#    'text': 'std.'},
#   {'x0': Decimal('527.991'),
#    'x1': Decimal('551.710'),
#    'top': Decimal('116.107'),
#    'bottom': Decimal('131.015'),
#    'text': 'ค่าสูงสุด'},
#   {'x0': Decimal('565.181'),
#    'x1': Decimal('588.431'),
#    'top': Decimal('116.107'),
#    'bottom': Decimal('131.015'),
#    'text': 'ค่าต่ําสุด'},
#   {'x0': Decimal('599.261'),
#    'x1': Decimal('610.442'),
#    'top': Decimal('116.107'),
#    'bottom': Decimal('131.015'),
#    'text': 'ครั้ง'},
#   {'x0': Decimal('612.128'),
#    'x1': Decimal('616.053'),
#    'top': Decimal('116.107'),
#    'bottom': Decimal('131.015'),
#    'text': '>'},
#   {'x0': Decimal('617.735'),
#    'x1': Decimal('628.222'),
#    'top': Decimal('116.107'),
#    'bottom': Decimal('131.015'),
#    'text': 'std.'},
#   {'x0': Decimal('675.831'),
#    'x1': Decimal('699.550'),
#    'top': Decimal('116.107'),
#    'bottom': Decimal('131.015'),
#    'text': 'ค่าสูงสุด'},
#   {'x0': Decimal('713.021'),
#    'x1': Decimal('736.270'),
#    'top': Decimal('116.107'),
#    'bottom': Decimal('131.015'),
#    'text': 'ค่าต่ําสุด'},
#   {'x0': Decimal('747.100'),
#    'x1': Decimal('758.281'),
#    'top': Decimal('116.107'),
#    'bottom': Decimal('131.015'),
#    'text': 'ครั้ง'},
#   {'x0': Decimal('759.966'),
#    'x1': Decimal('763.892'),
#    'top': Decimal('116.107'),
#    'bottom': Decimal('131.015'),
#    'text': '>'},
#   {'x0': Decimal('765.574'),
#    'x1': Decimal('776.061'),
#    'top': Decimal('116.107'),
#    'bottom': Decimal('131.015'),
#    'text': 'std.'}],
#  Decimal('131.245'): [{'x0': Decimal('193.311'),
#    'x1': Decimal('220.983'),
#    'top': Decimal('114.965'),
#    'bottom': Decimal('131.245'),
#    'text': 'รายเดือน'},
#   {'x0': Decimal('341.151'),
#    'x1': Decimal('368.823'),
#    'top': Decimal('114.965'),
#    'bottom': Decimal('131.245'),
#    'text': 'รายเดือน'},
#   {'x0': Decimal('488.991'),
#    'x1': Decimal('516.663'),
#    'top': Decimal('114.965'),
#    'bottom': Decimal('131.245'),
#    'text': 'รายเดือน'},
#   {'x0': Decimal('636.831'),
#    'x1': Decimal('664.503'),
#    'top': Decimal('114.965'),
#    'bottom': Decimal('131.245'),
#    'text': 'รายเดือน'},
#   {'x0': Decimal('784.671'),
#    'x1': Decimal('812.343'),
#    'top': Decimal('114.965'),
#    'bottom': Decimal('131.245'),
#    'text': 'รายเดือน'}],
#  Decimal('157.122'): [{'x0': Decimal('30.831'),
#    'x1': Decimal('65.623'),
#    'top': Decimal('135.360'),
#    'bottom': Decimal('157.122'),
#    'text': 'มกราคม'},
#   {'x0': Decimal('93.831'),
#    'x1': Decimal('98.860'),
#    'top': Decimal('135.360'),
#    'bottom': Decimal('157.122'),
#    'text': '#'},
#   {'x0': Decimal('130.790'),
#    'x1': Decimal('135.819'),
#    'top': Decimal('135.360'),
#    'bottom': Decimal('157.122'),
#    'text': '#'},
#   {'x0': Decimal('167.748'),
#    'x1': Decimal('172.777'),
#    'top': Decimal('135.360'),
#    'bottom': Decimal('157.122'),
#    'text': '#'},
#   {'x0': Decimal('204.707'),
#    'x1': Decimal('209.736'),
#    'top': Decimal('135.360'),
#    'bottom': Decimal('157.122'),
#    'text': '#'},
#   {'x0': Decimal('241.665'),
#    'x1': Decimal('246.694'),
#    'top': Decimal('135.360'),
#    'bottom': Decimal('157.122'),
#    'text': '#'},
#   {'x0': Decimal('278.624'),
#    'x1': Decimal('283.653'),
#    'top': Decimal('135.360'),
#    'bottom': Decimal('157.122'),
#    'text': '#'},
#   {'x0': Decimal('315.582'),
#    'x1': Decimal('320.611'),
#    'top': Decimal('135.360'),
#    'bottom': Decimal('157.122'),
#    'text': '#'},
#   {'x0': Decimal('352.541'),
#    'x1': Decimal('357.570'),
#    'top': Decimal('135.360'),
#    'bottom': Decimal('157.122'),
#    'text': '#'},
#   {'x0': Decimal('389.499'),
#    'x1': Decimal('394.529'),
#    'top': Decimal('135.360'),
#    'bottom': Decimal('157.122'),
#    'text': '#'},
#   {'x0': Decimal('426.458'),
#    'x1': Decimal('431.487'),
#    'top': Decimal('135.360'),
#    'bottom': Decimal('157.122'),
#    'text': '#'},
#   {'x0': Decimal('463.416'),
#    'x1': Decimal('468.446'),
#    'top': Decimal('135.360'),
#    'bottom': Decimal('157.122'),
#    'text': '#'},
#   {'x0': Decimal('500.375'),
#    'x1': Decimal('505.404'),
#    'top': Decimal('135.360'),
#    'bottom': Decimal('157.122'),
#    'text': '#'},
#   {'x0': Decimal('537.333'),
#    'x1': Decimal('542.363'),
#    'top': Decimal('135.360'),
#    'bottom': Decimal('157.122'),
#    'text': '#'},
#   {'x0': Decimal('574.292'),
#    'x1': Decimal('579.321'),
#    'top': Decimal('135.360'),
#    'bottom': Decimal('157.122'),
#    'text': '#'},
#   {'x0': Decimal('611.250'),
#    'x1': Decimal('616.280'),
#    'top': Decimal('135.360'),
#    'bottom': Decimal('157.122'),
#    'text': '#'},
#   {'x0': Decimal('648.209'),
#    'x1': Decimal('653.238'),
#    'top': Decimal('135.360'),
#    'bottom': Decimal('157.122'),
#    'text': '#'},
#   {'x0': Decimal('685.168'),
#    'x1': Decimal('690.197'),
#    'top': Decimal('135.360'),
#    'bottom': Decimal('157.122'),
#    'text': '#'},
#   {'x0': Decimal('722.126'),
#    'x1': Decimal('727.155'),
#    'top': Decimal('135.360'),
#    'bottom': Decimal('157.122'),
#    'text': '#'},
#   {'x0': Decimal('759.085'),
#    'x1': Decimal('764.114'),
#    'top': Decimal('135.360'),
#    'bottom': Decimal('157.122'),
#    'text': '#'},
#   {'x0': Decimal('796.043'),
#    'x1': Decimal('801.072'),
#    'top': Decimal('135.360'),
#    'bottom': Decimal('157.122'),
#    'text': '#'}],
#  Decimal('181.243'): [{'x0': Decimal('26.391'),
#    'x1': Decimal('70.191'),
#    'top': Decimal('159.480'),
#    'bottom': Decimal('181.243'),
#    'text': 'กุมภาพันธ์'},
#   {'x0': Decimal('93.831'),
#    'x1': Decimal('98.860'),
#    'top': Decimal('159.480'),
#    'bottom': Decimal('181.243'),
#    'text': '#'},
#   {'x0': Decimal('130.790'),
#    'x1': Decimal('135.819'),
#    'top': Decimal('159.480'),
#    'bottom': Decimal('181.243'),
#    'text': '#'},
#   {'x0': Decimal('167.748'),
#    'x1': Decimal('172.777'),
#    'top': Decimal('159.480'),
#    'bottom': Decimal('181.243'),
#    'text': '#'},
#   {'x0': Decimal('204.707'),
#    'x1': Decimal('209.736'),
#    'top': Decimal('159.480'),
#    'bottom': Decimal('181.243'),
#    'text': '#'},
#   {'x0': Decimal('241.665'),
#    'x1': Decimal('246.694'),
#    'top': Decimal('159.480'),
#    'bottom': Decimal('181.243'),
#    'text': '#'},
#   {'x0': Decimal('278.624'),
#    'x1': Decimal('283.653'),
#    'top': Decimal('159.480'),
#    'bottom': Decimal('181.243'),
#    'text': '#'},
#   {'x0': Decimal('315.582'),
#    'x1': Decimal('320.611'),
#    'top': Decimal('159.480'),
#    'bottom': Decimal('181.243'),
#    'text': '#'},
#   {'x0': Decimal('352.541'),
#    'x1': Decimal('357.570'),
#    'top': Decimal('159.480'),
#    'bottom': Decimal('181.243'),
#    'text': '#'},
#   {'x0': Decimal('389.499'),
#    'x1': Decimal('394.529'),
#    'top': Decimal('159.480'),
#    'bottom': Decimal('181.243'),
#    'text': '#'},
#   {'x0': Decimal('426.458'),
#    'x1': Decimal('431.487'),
#    'top': Decimal('159.480'),
#    'bottom': Decimal('181.243'),
#    'text': '#'},
#   {'x0': Decimal('463.416'),
#    'x1': Decimal('468.446'),
#    'top': Decimal('159.480'),
#    'bottom': Decimal('181.243'),
#    'text': '#'},
#   {'x0': Decimal('500.375'),
#    'x1': Decimal('505.404'),
#    'top': Decimal('159.480'),
#    'bottom': Decimal('181.243'),
#    'text': '#'},
#   {'x0': Decimal('537.333'),
#    'x1': Decimal('542.363'),
#    'top': Decimal('159.480'),
#    'bottom': Decimal('181.243'),
#    'text': '#'},
#   {'x0': Decimal('574.292'),
#    'x1': Decimal('579.321'),
#    'top': Decimal('159.480'),
#    'bottom': Decimal('181.243'),
#    'text': '#'},
#   {'x0': Decimal('611.250'),
#    'x1': Decimal('616.280'),
#    'top': Decimal('159.480'),
#    'bottom': Decimal('181.243'),
#    'text': '#'},
#   {'x0': Decimal('648.209'),
#    'x1': Decimal('653.238'),
#    'top': Decimal('159.480'),
#    'bottom': Decimal('181.243'),
#    'text': '#'},
#   {'x0': Decimal('685.168'),
#    'x1': Decimal('690.197'),
#    'top': Decimal('159.480'),
#    'bottom': Decimal('181.243'),
#    'text': '#'},
#   {'x0': Decimal('722.126'),
#    'x1': Decimal('727.155'),
#    'top': Decimal('159.480'),
#    'bottom': Decimal('181.243'),
#    'text': '#'},
#   {'x0': Decimal('759.085'),
#    'x1': Decimal('764.114'),
#    'top': Decimal('159.480'),
#    'bottom': Decimal('181.243'),
#    'text': '#'},
#   {'x0': Decimal('796.043'),
#    'x1': Decimal('801.072'),
#    'top': Decimal('159.480'),
#    'bottom': Decimal('181.243'),
#    'text': '#'}],
#  Decimal('205.363'): [{'x0': Decimal('32.992'),
#    'x1': Decimal('63.586'),
#    'top': Decimal('183.600'),
#    'bottom': Decimal('205.363'),
#    'text': 'มีนาคม'},
#   {'x0': Decimal('93.833'),
#    'x1': Decimal('98.862'),
#    'top': Decimal('183.600'),
#    'bottom': Decimal('205.363'),
#    'text': '#'},
#   {'x0': Decimal('130.791'),
#    'x1': Decimal('135.820'),
#    'top': Decimal('183.600'),
#    'bottom': Decimal('205.363'),
#    'text': '#'},
#   {'x0': Decimal('167.750'),
#    'x1': Decimal('172.779'),
#    'top': Decimal('183.600'),
#    'bottom': Decimal('205.363'),
#    'text': '#'},
#   {'x0': Decimal('204.708'),
#    'x1': Decimal('209.737'),
#    'top': Decimal('183.600'),
#    'bottom': Decimal('205.363'),
#    'text': '#'},
#   {'x0': Decimal('241.667'),
#    'x1': Decimal('246.696'),
#    'top': Decimal('183.600'),
#    'bottom': Decimal('205.363'),
#    'text': '#'},
#   {'x0': Decimal('278.625'),
#    'x1': Decimal('283.654'),
#    'top': Decimal('183.600'),
#    'bottom': Decimal('205.363'),
#    'text': '#'},
#   {'x0': Decimal('315.584'),
#    'x1': Decimal('320.613'),
#    'top': Decimal('183.600'),
#    'bottom': Decimal('205.363'),
#    'text': '#'},
#   {'x0': Decimal('352.542'),
#    'x1': Decimal('357.572'),
#    'top': Decimal('183.600'),
#    'bottom': Decimal('205.363'),
#    'text': '#'},
#   {'x0': Decimal('389.501'),
#    'x1': Decimal('394.530'),
#    'top': Decimal('183.600'),
#    'bottom': Decimal('205.363'),
#    'text': '#'},
#   {'x0': Decimal('426.459'),
#    'x1': Decimal('431.489'),
#    'top': Decimal('183.600'),
#    'bottom': Decimal('205.363'),
#    'text': '#'},
#   {'x0': Decimal('463.418'),
#    'x1': Decimal('468.447'),
#    'top': Decimal('183.600'),
#    'bottom': Decimal('205.363'),
#    'text': '#'},
#   {'x0': Decimal('500.376'),
#    'x1': Decimal('505.406'),
#    'top': Decimal('183.600'),
#    'bottom': Decimal('205.363'),
#    'text': '#'},
#   {'x0': Decimal('537.335'),
#    'x1': Decimal('542.364'),
#    'top': Decimal('183.600'),
#    'bottom': Decimal('205.363'),
#    'text': '#'},
#   {'x0': Decimal('574.293'),
#    'x1': Decimal('579.323'),
#    'top': Decimal('183.600'),
#    'bottom': Decimal('205.363'),
#    'text': '#'},
#   {'x0': Decimal('611.252'),
#    'x1': Decimal('616.281'),
#    'top': Decimal('183.600'),
#    'bottom': Decimal('205.363'),
#    'text': '#'},
#   {'x0': Decimal('648.211'),
#    'x1': Decimal('653.240'),
#    'top': Decimal('183.600'),
#    'bottom': Decimal('205.363'),
#    'text': '#'},
#   {'x0': Decimal('685.169'),
#    'x1': Decimal('690.198'),
#    'top': Decimal('183.600'),
#    'bottom': Decimal('205.363'),
#    'text': '#'},
#   {'x0': Decimal('722.128'),
#    'x1': Decimal('727.157'),
#    'top': Decimal('183.600'),
#    'bottom': Decimal('205.363'),
#    'text': '#'},
#   {'x0': Decimal('759.086'),
#    'x1': Decimal('764.115'),
#    'top': Decimal('183.600'),
#    'bottom': Decimal('205.363'),
#    'text': '#'},
#   {'x0': Decimal('796.045'),
#    'x1': Decimal('801.074'),
#    'top': Decimal('183.600'),
#    'bottom': Decimal('205.363'),
#    'text': '#'}],
#  Decimal('229.483'): [{'x0': Decimal('31.792'),
#    'x1': Decimal('64.688'),
#    'top': Decimal('207.721'),
#    'bottom': Decimal('229.483'),
#    'text': 'เมษายน'},
#   {'x0': Decimal('93.833'),
#    'x1': Decimal('98.862'),
#    'top': Decimal('207.721'),
#    'bottom': Decimal('229.483'),
#    'text': '#'},
#   {'x0': Decimal('130.791'),
#    'x1': Decimal('135.820'),
#    'top': Decimal('207.721'),
#    'bottom': Decimal('229.483'),
#    'text': '#'},
#   {'x0': Decimal('167.750'),
#    'x1': Decimal('172.779'),
#    'top': Decimal('207.721'),
#    'bottom': Decimal('229.483'),
#    'text': '#'},
#   {'x0': Decimal('204.708'),
#    'x1': Decimal('209.737'),
#    'top': Decimal('207.721'),
#    'bottom': Decimal('229.483'),
#    'text': '#'},
#   {'x0': Decimal('241.667'),
#    'x1': Decimal('246.696'),
#    'top': Decimal('207.721'),
#    'bottom': Decimal('229.483'),
#    'text': '#'},
#   {'x0': Decimal('278.625'),
#    'x1': Decimal('283.654'),
#    'top': Decimal('207.721'),
#    'bottom': Decimal('229.483'),
#    'text': '#'},
#   {'x0': Decimal('315.584'),
#    'x1': Decimal('320.613'),
#    'top': Decimal('207.721'),
#    'bottom': Decimal('229.483'),
#    'text': '#'},
#   {'x0': Decimal('352.542'),
#    'x1': Decimal('357.572'),
#    'top': Decimal('207.721'),
#    'bottom': Decimal('229.483'),
#    'text': '#'},
#   {'x0': Decimal('389.501'),
#    'x1': Decimal('394.530'),
#    'top': Decimal('207.721'),
#    'bottom': Decimal('229.483'),
#    'text': '#'},
#   {'x0': Decimal('426.459'),
#    'x1': Decimal('431.489'),
#    'top': Decimal('207.721'),
#    'bottom': Decimal('229.483'),
#    'text': '#'},
#   {'x0': Decimal('463.418'),
#    'x1': Decimal('468.447'),
#    'top': Decimal('207.721'),
#    'bottom': Decimal('229.483'),
#    'text': '#'},
#   {'x0': Decimal('500.376'),
#    'x1': Decimal('505.406'),
#    'top': Decimal('207.721'),
#    'bottom': Decimal('229.483'),
#    'text': '#'},
#   {'x0': Decimal('537.335'),
#    'x1': Decimal('542.364'),
#    'top': Decimal('207.721'),
#    'bottom': Decimal('229.483'),
#    'text': '#'},
#   {'x0': Decimal('574.293'),
#    'x1': Decimal('579.323'),
#    'top': Decimal('207.721'),
#    'bottom': Decimal('229.483'),
#    'text': '#'},
#   {'x0': Decimal('611.252'),
#    'x1': Decimal('616.281'),
#    'top': Decimal('207.721'),
#    'bottom': Decimal('229.483'),
#    'text': '#'},
#   {'x0': Decimal('648.211'),
#    'x1': Decimal('653.240'),
#    'top': Decimal('207.721'),
#    'bottom': Decimal('229.483'),
#    'text': '#'},
#   {'x0': Decimal('685.169'),
#    'x1': Decimal('690.198'),
#    'top': Decimal('207.721'),
#    'bottom': Decimal('229.483'),
#    'text': '#'},
#   {'x0': Decimal('722.128'),
#    'x1': Decimal('727.157'),
#    'top': Decimal('207.721'),
#    'bottom': Decimal('229.483'),
#    'text': '#'},
#   {'x0': Decimal('759.086'),
#    'x1': Decimal('764.115'),
#    'top': Decimal('207.721'),
#    'bottom': Decimal('229.483'),
#    'text': '#'},
#   {'x0': Decimal('796.045'),
#    'x1': Decimal('801.074'),
#    'top': Decimal('207.721'),
#    'bottom': Decimal('229.483'),
#    'text': '#'}],
#  Decimal('253.604'): [{'x0': Decimal('26.393'),
#    'x1': Decimal('70.162'),
#    'top': Decimal('231.841'),
#    'bottom': Decimal('253.604'),
#    'text': 'พฤษภาคม'},
#   {'x0': Decimal('93.833'),
#    'x1': Decimal('98.862'),
#    'top': Decimal('231.841'),
#    'bottom': Decimal('253.604'),
#    'text': '#'},
#   {'x0': Decimal('130.791'),
#    'x1': Decimal('135.820'),
#    'top': Decimal('231.841'),
#    'bottom': Decimal('253.604'),
#    'text': '#'},
#   {'x0': Decimal('167.750'),
#    'x1': Decimal('172.779'),
#    'top': Decimal('231.841'),
#    'bottom': Decimal('253.604'),
#    'text': '#'},
#   {'x0': Decimal('204.708'),
#    'x1': Decimal('209.737'),
#    'top': Decimal('231.841'),
#    'bottom': Decimal('253.604'),
#    'text': '#'},
#   {'x0': Decimal('241.667'),
#    'x1': Decimal('246.696'),
#    'top': Decimal('231.841'),
#    'bottom': Decimal('253.604'),
#    'text': '#'},
#   {'x0': Decimal('278.625'),
#    'x1': Decimal('283.654'),
#    'top': Decimal('231.841'),
#    'bottom': Decimal('253.604'),
#    'text': '#'},
#   {'x0': Decimal('315.584'),
#    'x1': Decimal('320.613'),
#    'top': Decimal('231.841'),
#    'bottom': Decimal('253.604'),
#    'text': '#'},
#   {'x0': Decimal('352.542'),
#    'x1': Decimal('357.572'),
#    'top': Decimal('231.841'),
#    'bottom': Decimal('253.604'),
#    'text': '#'},
#   {'x0': Decimal('389.501'),
#    'x1': Decimal('394.530'),
#    'top': Decimal('231.841'),
#    'bottom': Decimal('253.604'),
#    'text': '#'},
#   {'x0': Decimal('426.459'),
#    'x1': Decimal('431.489'),
#    'top': Decimal('231.841'),
#    'bottom': Decimal('253.604'),
#    'text': '#'},
#   {'x0': Decimal('463.418'),
#    'x1': Decimal('468.447'),
#    'top': Decimal('231.841'),
#    'bottom': Decimal('253.604'),
#    'text': '#'},
#   {'x0': Decimal('500.376'),
#    'x1': Decimal('505.406'),
#    'top': Decimal('231.841'),
#    'bottom': Decimal('253.604'),
#    'text': '#'},
#   {'x0': Decimal('537.335'),
#    'x1': Decimal('542.364'),
#    'top': Decimal('231.841'),
#    'bottom': Decimal('253.604'),
#    'text': '#'},
#   {'x0': Decimal('574.293'),
#    'x1': Decimal('579.323'),
#    'top': Decimal('231.841'),
#    'bottom': Decimal('253.604'),
#    'text': '#'},
#   {'x0': Decimal('611.252'),
#    'x1': Decimal('616.281'),
#    'top': Decimal('231.841'),
#    'bottom': Decimal('253.604'),
#    'text': '#'},
#   {'x0': Decimal('648.211'),
#    'x1': Decimal('653.240'),
#    'top': Decimal('231.841'),
#    'bottom': Decimal('253.604'),
#    'text': '#'},
#   {'x0': Decimal('685.169'),
#    'x1': Decimal('690.198'),
#    'top': Decimal('231.841'),
#    'bottom': Decimal('253.604'),
#    'text': '#'},
#   {'x0': Decimal('722.128'),
#    'x1': Decimal('727.157'),
#    'top': Decimal('231.841'),
#    'bottom': Decimal('253.604'),
#    'text': '#'},
#   {'x0': Decimal('759.086'),
#    'x1': Decimal('764.115'),
#    'top': Decimal('231.841'),
#    'bottom': Decimal('253.604'),
#    'text': '#'},
#   {'x0': Decimal('796.045'),
#    'x1': Decimal('801.074'),
#    'top': Decimal('231.841'),
#    'bottom': Decimal('253.604'),
#    'text': '#'}],
#  Decimal('277.724'): [{'x0': Decimal('29.992'),
#    'x1': Decimal('66.609'),
#    'top': Decimal('255.961'),
#    'bottom': Decimal('277.724'),
#    'text': 'มิถุนายน'},
#   {'x0': Decimal('93.833'),
#    'x1': Decimal('98.862'),
#    'top': Decimal('255.961'),
#    'bottom': Decimal('277.724'),
#    'text': '#'},
#   {'x0': Decimal('130.791'),
#    'x1': Decimal('135.820'),
#    'top': Decimal('255.961'),
#    'bottom': Decimal('277.724'),
#    'text': '#'},
#   {'x0': Decimal('167.750'),
#    'x1': Decimal('172.779'),
#    'top': Decimal('255.961'),
#    'bottom': Decimal('277.724'),
#    'text': '#'},
#   {'x0': Decimal('204.708'),
#    'x1': Decimal('209.737'),
#    'top': Decimal('255.961'),
#    'bottom': Decimal('277.724'),
#    'text': '#'},
#   {'x0': Decimal('241.667'),
#    'x1': Decimal('246.696'),
#    'top': Decimal('255.961'),
#    'bottom': Decimal('277.724'),
#    'text': '#'},
#   {'x0': Decimal('278.625'),
#    'x1': Decimal('283.654'),
#    'top': Decimal('255.961'),
#    'bottom': Decimal('277.724'),
#    'text': '#'},
#   {'x0': Decimal('315.584'),
#    'x1': Decimal('320.613'),
#    'top': Decimal('255.961'),
#    'bottom': Decimal('277.724'),
#    'text': '#'},
#   {'x0': Decimal('352.542'),
#    'x1': Decimal('357.572'),
#    'top': Decimal('255.961'),
#    'bottom': Decimal('277.724'),
#    'text': '#'},
#   {'x0': Decimal('389.501'),
#    'x1': Decimal('394.530'),
#    'top': Decimal('255.961'),
#    'bottom': Decimal('277.724'),
#    'text': '#'},
#   {'x0': Decimal('426.459'),
#    'x1': Decimal('431.489'),
#    'top': Decimal('255.961'),
#    'bottom': Decimal('277.724'),
#    'text': '#'},
#   {'x0': Decimal('463.418'),
#    'x1': Decimal('468.447'),
#    'top': Decimal('255.961'),
#    'bottom': Decimal('277.724'),
#    'text': '#'},
#   {'x0': Decimal('500.376'),
#    'x1': Decimal('505.406'),
#    'top': Decimal('255.961'),
#    'bottom': Decimal('277.724'),
#    'text': '#'},
#   {'x0': Decimal('537.335'),
#    'x1': Decimal('542.364'),
#    'top': Decimal('255.961'),
#    'bottom': Decimal('277.724'),
#    'text': '#'},
#   {'x0': Decimal('574.293'),
#    'x1': Decimal('579.323'),
#    'top': Decimal('255.961'),
#    'bottom': Decimal('277.724'),
#    'text': '#'},
#   {'x0': Decimal('611.252'),
#    'x1': Decimal('616.281'),
#    'top': Decimal('255.961'),
#    'bottom': Decimal('277.724'),
#    'text': '#'},
#   {'x0': Decimal('648.211'),
#    'x1': Decimal('653.240'),
#    'top': Decimal('255.961'),
#    'bottom': Decimal('277.724'),
#    'text': '#'},
#   {'x0': Decimal('685.169'),
#    'x1': Decimal('690.198'),
#    'top': Decimal('255.961'),
#    'bottom': Decimal('277.724'),
#    'text': '#'},
#   {'x0': Decimal('722.128'),
#    'x1': Decimal('727.157'),
#    'top': Decimal('255.961'),
#    'bottom': Decimal('277.724'),
#    'text': '#'},
#   {'x0': Decimal('759.086'),
#    'x1': Decimal('764.115'),
#    'top': Decimal('255.961'),
#    'bottom': Decimal('277.724'),
#    'text': '#'},
#   {'x0': Decimal('796.045'),
#    'x1': Decimal('801.074'),
#    'top': Decimal('255.961'),
#    'bottom': Decimal('277.724'),
#    'text': '#'}],
#  Decimal('301.844'): [{'x0': Decimal('27.833'),
#    'x1': Decimal('68.642'),
#    'top': Decimal('280.082'),
#    'bottom': Decimal('301.844'),
#    'text': 'กรกฎาคม'},
#   {'x0': Decimal('93.833'),
#    'x1': Decimal('98.862'),
#    'top': Decimal('280.082'),
#    'bottom': Decimal('301.844'),
#    'text': '#'},
#   {'x0': Decimal('130.791'),
#    'x1': Decimal('135.820'),
#    'top': Decimal('280.082'),
#    'bottom': Decimal('301.844'),
#    'text': '#'},
#   {'x0': Decimal('167.750'),
#    'x1': Decimal('172.779'),
#    'top': Decimal('280.082'),
#    'bottom': Decimal('301.844'),
#    'text': '#'},
#   {'x0': Decimal('204.708'),
#    'x1': Decimal('209.737'),
#    'top': Decimal('280.082'),
#    'bottom': Decimal('301.844'),
#    'text': '#'},
#   {'x0': Decimal('241.667'),
#    'x1': Decimal('246.696'),
#    'top': Decimal('280.082'),
#    'bottom': Decimal('301.844'),
#    'text': '#'},
#   {'x0': Decimal('278.625'),
#    'x1': Decimal('283.654'),
#    'top': Decimal('280.082'),
#    'bottom': Decimal('301.844'),
#    'text': '#'},
#   {'x0': Decimal('315.584'),
#    'x1': Decimal('320.613'),
#    'top': Decimal('280.082'),
#    'bottom': Decimal('301.844'),
#    'text': '#'},
#   {'x0': Decimal('352.542'),
#    'x1': Decimal('357.572'),
#    'top': Decimal('280.082'),
#    'bottom': Decimal('301.844'),
#    'text': '#'},
#   {'x0': Decimal('389.501'),
#    'x1': Decimal('394.530'),
#    'top': Decimal('280.082'),
#    'bottom': Decimal('301.844'),
#    'text': '#'},
#   {'x0': Decimal('426.459'),
#    'x1': Decimal('431.489'),
#    'top': Decimal('280.082'),
#    'bottom': Decimal('301.844'),
#    'text': '#'},
#   {'x0': Decimal('463.418'),
#    'x1': Decimal('468.447'),
#    'top': Decimal('280.082'),
#    'bottom': Decimal('301.844'),
#    'text': '#'},
#   {'x0': Decimal('500.376'),
#    'x1': Decimal('505.406'),
#    'top': Decimal('280.082'),
#    'bottom': Decimal('301.844'),
#    'text': '#'},
#   {'x0': Decimal('537.335'),
#    'x1': Decimal('542.364'),
#    'top': Decimal('280.082'),
#    'bottom': Decimal('301.844'),
#    'text': '#'},
#   {'x0': Decimal('574.293'),
#    'x1': Decimal('579.323'),
#    'top': Decimal('280.082'),
#    'bottom': Decimal('301.844'),
#    'text': '#'},
#   {'x0': Decimal('611.252'),
#    'x1': Decimal('616.281'),
#    'top': Decimal('280.082'),
#    'bottom': Decimal('301.844'),
#    'text': '#'},
#   {'x0': Decimal('648.211'),
#    'x1': Decimal('653.240'),
#    'top': Decimal('280.082'),
#    'bottom': Decimal('301.844'),
#    'text': '#'},
#   {'x0': Decimal('685.169'),
#    'x1': Decimal('690.198'),
#    'top': Decimal('280.082'),
#    'bottom': Decimal('301.844'),
#    'text': '#'},
#   {'x0': Decimal('722.128'),
#    'x1': Decimal('727.157'),
#    'top': Decimal('280.082'),
#    'bottom': Decimal('301.844'),
#    'text': '#'},
#   {'x0': Decimal('759.086'),
#    'x1': Decimal('764.115'),
#    'top': Decimal('280.082'),
#    'bottom': Decimal('301.844'),
#    'text': '#'},
#   {'x0': Decimal('796.045'),
#    'x1': Decimal('801.074'),
#    'top': Decimal('280.082'),
#    'bottom': Decimal('301.844'),
#    'text': '#'}],
#  Decimal('325.965'): [{'x0': Decimal('30.593'),
#    'x1': Decimal('65.975'),
#    'top': Decimal('304.202'),
#    'bottom': Decimal('325.965'),
#    'text': 'สิงหาคม'},
#   {'x0': Decimal('93.833'),
#    'x1': Decimal('98.862'),
#    'top': Decimal('304.202'),
#    'bottom': Decimal('325.965'),
#    'text': '#'},
#   {'x0': Decimal('130.791'),
#    'x1': Decimal('135.820'),
#    'top': Decimal('304.202'),
#    'bottom': Decimal('325.965'),
#    'text': '#'},
#   {'x0': Decimal('167.750'),
#    'x1': Decimal('172.779'),
#    'top': Decimal('304.202'),
#    'bottom': Decimal('325.965'),
#    'text': '#'},
#   {'x0': Decimal('204.708'),
#    'x1': Decimal('209.737'),
#    'top': Decimal('304.202'),
#    'bottom': Decimal('325.965'),
#    'text': '#'},
#   {'x0': Decimal('241.667'),
#    'x1': Decimal('246.696'),
#    'top': Decimal('304.202'),
#    'bottom': Decimal('325.965'),
#    'text': '#'},
#   {'x0': Decimal('278.625'),
#    'x1': Decimal('283.654'),
#    'top': Decimal('304.202'),
#    'bottom': Decimal('325.965'),
#    'text': '#'},
#   {'x0': Decimal('315.584'),
#    'x1': Decimal('320.613'),
#    'top': Decimal('304.202'),
#    'bottom': Decimal('325.965'),
#    'text': '#'},
#   {'x0': Decimal('352.542'),
#    'x1': Decimal('357.572'),
#    'top': Decimal('304.202'),
#    'bottom': Decimal('325.965'),
#    'text': '#'},
#   {'x0': Decimal('389.501'),
#    'x1': Decimal('394.530'),
#    'top': Decimal('304.202'),
#    'bottom': Decimal('325.965'),
#    'text': '#'},
#   {'x0': Decimal('426.459'),
#    'x1': Decimal('431.489'),
#    'top': Decimal('304.202'),
#    'bottom': Decimal('325.965'),
#    'text': '#'},
#   {'x0': Decimal('463.418'),
#    'x1': Decimal('468.447'),
#    'top': Decimal('304.202'),
#    'bottom': Decimal('325.965'),
#    'text': '#'},
#   {'x0': Decimal('500.376'),
#    'x1': Decimal('505.406'),
#    'top': Decimal('304.202'),
#    'bottom': Decimal('325.965'),
#    'text': '#'},
#   {'x0': Decimal('537.335'),
#    'x1': Decimal('542.364'),
#    'top': Decimal('304.202'),
#    'bottom': Decimal('325.965'),
#    'text': '#'},
#   {'x0': Decimal('574.293'),
#    'x1': Decimal('579.323'),
#    'top': Decimal('304.202'),
#    'bottom': Decimal('325.965'),
#    'text': '#'},
#   {'x0': Decimal('611.252'),
#    'x1': Decimal('616.281'),
#    'top': Decimal('304.202'),
#    'bottom': Decimal('325.965'),
#    'text': '#'},
#   {'x0': Decimal('648.211'),
#    'x1': Decimal('653.240'),
#    'top': Decimal('304.202'),
#    'bottom': Decimal('325.965'),
#    'text': '#'},
#   {'x0': Decimal('685.169'),
#    'x1': Decimal('690.198'),
#    'top': Decimal('304.202'),
#    'bottom': Decimal('325.965'),
#    'text': '#'},
#   {'x0': Decimal('722.128'),
#    'x1': Decimal('727.157'),
#    'top': Decimal('304.202'),
#    'bottom': Decimal('325.965'),
#    'text': '#'},
#   {'x0': Decimal('759.086'),
#    'x1': Decimal('764.115'),
#    'top': Decimal('304.202'),
#    'bottom': Decimal('325.965'),
#    'text': '#'},
#   {'x0': Decimal('796.045'),
#    'x1': Decimal('801.074'),
#    'top': Decimal('304.202'),
#    'bottom': Decimal('325.965'),
#    'text': '#'}],
#  Decimal('350.085'): [{'x0': Decimal('30.593'),
#    'x1': Decimal('65.992'),
#    'top': Decimal('328.322'),
#    'bottom': Decimal('350.085'),
#    'text': 'กันยายน'},
#   {'x0': Decimal('87.473'),
#    'x1': Decimal('105.075'),
#    'top': Decimal('328.322'),
#    'bottom': Decimal('350.085'),
#    'text': '73.0'},
#   {'x0': Decimal('126.949'),
#    'x1': Decimal('139.522'),
#    'top': Decimal('328.322'),
#    'bottom': Decimal('350.085'),
#    'text': '0.0'},
#   {'x0': Decimal('156.227'),
#    'x1': Decimal('184.162'),
#    'top': Decimal('328.322'),
#    'bottom': Decimal('350.085'),
#    'text': '0/380*'},
#   {'x0': Decimal('198.335'),
#    'x1': Decimal('215.937'),
#    'top': Decimal('328.322'),
#    'bottom': Decimal('350.085'),
#    'text': '15.2'},
#   {'x0': Decimal('232.771'),
#    'x1': Decimal('255.403'),
#    'top': Decimal('328.322'),
#    'bottom': Decimal('350.085'),
#    'text': '115.0'},
#   {'x0': Decimal('272.246'),
#    'x1': Decimal('289.848'),
#    'top': Decimal('328.322'),
#    'bottom': Decimal('350.085'),
#    'text': '11.0'},
#   {'x0': Decimal('306.562'),
#    'x1': Decimal('329.467'),
#    'top': Decimal('328.322'),
#    'bottom': Decimal('350.085'),
#    'text': '0/562'},
#   {'x0': Decimal('346.152'),
#    'x1': Decimal('363.754'),
#    'top': Decimal('328.322'),
#    'bottom': Decimal('350.085'),
#    'text': '38.6'},
#   {'x0': Decimal('383.108'),
#    'x1': Decimal('400.710'),
#    'top': Decimal('328.322'),
#    'bottom': Decimal('350.085'),
#    'text': '19.1'},
#   {'x0': Decimal('422.584'),
#    'x1': Decimal('435.157'),
#    'top': Decimal('328.322'),
#    'bottom': Decimal('350.085'),
#    'text': '0.7'},
#   {'x0': Decimal('454.381'),
#    'x1': Decimal('477.286'),
#    'top': Decimal('328.322'),
#    'bottom': Decimal('350.085'),
#    'text': '0/635'},
#   {'x0': Decimal('496.490'),
#    'x1': Decimal('509.063'),
#    'top': Decimal('328.322'),
#    'bottom': Decimal('350.085'),
#    'text': '4.1'},
#   {'x0': Decimal('530.927'),
#    'x1': Decimal('548.529'),
#    'top': Decimal('328.322'),
#    'bottom': Decimal('350.085'),
#    'text': '30.0'},
#   {'x0': Decimal('570.403'),
#    'x1': Decimal('582.976'),
#    'top': Decimal('328.322'),
#    'bottom': Decimal('350.085'),
#    'text': '0.0'},
#   {'x0': Decimal('602.199'),
#    'x1': Decimal('625.105'),
#    'top': Decimal('328.322'),
#    'bottom': Decimal('350.085'),
#    'text': '0/625'},
#   {'x0': Decimal('644.309'),
#    'x1': Decimal('656.882'),
#    'top': Decimal('328.322'),
#    'bottom': Decimal('350.085'),
#    'text': '1.4'},
#   {'x0': Decimal('676.226'),
#    'x1': Decimal('698.858'),
#    'top': Decimal('328.322'),
#    'bottom': Decimal('350.085'),
#    'text': '285.7'},
#   {'x0': Decimal('715.701'),
#    'x1': Decimal('733.303'),
#    'top': Decimal('328.322'),
#    'bottom': Decimal('350.085'),
#    'text': '81.5'},
#   {'x0': Decimal('750.017'),
#    'x1': Decimal('772.922'),
#    'top': Decimal('328.322'),
#    'bottom': Decimal('350.085'),
#    'text': '21/30'},
#   {'x0': Decimal('787.087'),
#    'x1': Decimal('809.718'),
#    'top': Decimal('328.322'),
#    'bottom': Decimal('350.085'),
#    'text': '163.2'}],
#  Decimal('374.205'): [{'x0': Decimal('33.594'),
#    'x1': Decimal('62.888'),
#    'top': Decimal('352.443'),
#    'bottom': Decimal('374.205'),
#    'text': 'ตุลาคม'},
#   {'x0': Decimal('87.473'),
#    'x1': Decimal('105.075'),
#    'top': Decimal('352.443'),
#    'bottom': Decimal('374.205'),
#    'text': '92.0'},
#   {'x0': Decimal('126.949'),
#    'x1': Decimal('139.522'),
#    'top': Decimal('352.443'),
#    'bottom': Decimal('374.205'),
#    'text': '1.0'},
#   {'x0': Decimal('158.746'),
#    'x1': Decimal('181.652'),
#    'top': Decimal('352.443'),
#    'bottom': Decimal('374.205'),
#    'text': '0/620'},
#   {'x0': Decimal('198.336'),
#    'x1': Decimal('215.939'),
#    'top': Decimal('352.443'),
#    'bottom': Decimal('374.205'),
#    'text': '22.9'},
#   {'x0': Decimal('232.773'),
#    'x1': Decimal('255.404'),
#    'top': Decimal('352.443'),
#    'bottom': Decimal('374.205'),
#    'text': '150.0'},
#   {'x0': Decimal('272.247'),
#    'x1': Decimal('289.850'),
#    'top': Decimal('352.443'),
#    'bottom': Decimal('374.205'),
#    'text': '15.0'},
#   {'x0': Decimal('306.563'),
#    'x1': Decimal('329.469'),
#    'top': Decimal('352.443'),
#    'bottom': Decimal('374.205'),
#    'text': '0/579'},
#   {'x0': Decimal('346.154'),
#    'x1': Decimal('363.756'),
#    'top': Decimal('352.443'),
#    'bottom': Decimal('374.205'),
#    'text': '50.9'},
#   {'x0': Decimal('383.109'),
#    'x1': Decimal('400.711'),
#    'top': Decimal('352.443'),
#    'bottom': Decimal('374.205'),
#    'text': '10.7'},
#   {'x0': Decimal('422.585'),
#    'x1': Decimal('435.158'),
#    'top': Decimal('352.443'),
#    'bottom': Decimal('374.205'),
#    'text': '1.1'},
#   {'x0': Decimal('454.382'),
#    'x1': Decimal('477.288'),
#    'top': Decimal('352.443'),
#    'bottom': Decimal('374.205'),
#    'text': '0/694'},
#   {'x0': Decimal('496.492'),
#    'x1': Decimal('509.065'),
#    'top': Decimal('352.443'),
#    'bottom': Decimal('374.205'),
#    'text': '3.8'},
#   {'x0': Decimal('530.928'),
#    'x1': Decimal('548.530'),
#    'top': Decimal('352.443'),
#    'bottom': Decimal('374.205'),
#    'text': '18.0'},
#   {'x0': Decimal('570.404'),
#    'x1': Decimal('582.977'),
#    'top': Decimal('352.443'),
#    'bottom': Decimal('374.205'),
#    'text': '0.0'},
#   {'x0': Decimal('597.161'),
#    'x1': Decimal('630.125'),
#    'top': Decimal('352.443'),
#    'bottom': Decimal('374.205'),
#    'text': '0/334**'},
#   {'x0': Decimal('644.309'),
#    'x1': Decimal('656.882'),
#    'top': Decimal('352.443'),
#    'bottom': Decimal('374.205'),
#    'text': '2.8'},
#   {'x0': Decimal('676.226'),
#    'x1': Decimal('698.858'),
#    'top': Decimal('352.443'),
#    'bottom': Decimal('374.205'),
#    'text': '313.4'},
#   {'x0': Decimal('713.180'),
#    'x1': Decimal('735.812'),
#    'top': Decimal('352.443'),
#    'bottom': Decimal('374.205'),
#    'text': '117.9'},
#   {'x0': Decimal('750.015'),
#    'x1': Decimal('772.921'),
#    'top': Decimal('352.443'),
#    'bottom': Decimal('374.205'),
#    'text': '30/31'},
#   {'x0': Decimal('787.085'),
#    'x1': Decimal('809.716'),
#    'top': Decimal('352.443'),
#    'bottom': Decimal('374.205'),
#    'text': '198.3'}],
#  Decimal('398.326'): [{'x0': Decimal('24.113'),
#    'x1': Decimal('72.484'),
#    'top': Decimal('376.563'),
#    'bottom': Decimal('398.326'),
#    'text': 'พฤศจิกายน'},
#   {'x0': Decimal('87.473'),
#    'x1': Decimal('105.075'),
#    'top': Decimal('376.563'),
#    'bottom': Decimal('398.326'),
#    'text': '71.9'},
#   {'x0': Decimal('126.949'),
#    'x1': Decimal('139.522'),
#    'top': Decimal('376.563'),
#    'bottom': Decimal('398.326'),
#    'text': '5.4'},
#   {'x0': Decimal('156.227'),
#    'x1': Decimal('184.162'),
#    'top': Decimal('376.563'),
#    'bottom': Decimal('398.326'),
#    'text': '0/482*'},
#   {'x0': Decimal('198.335'),
#    'x1': Decimal('215.937'),
#    'top': Decimal('376.563'),
#    'bottom': Decimal('398.326'),
#    'text': '28.2'},
#   {'x0': Decimal('235.290'),
#    'x1': Decimal('252.893'),
#    'top': Decimal('376.563'),
#    'bottom': Decimal('398.326'),
#    'text': '98.0'},
#   {'x0': Decimal('272.246'),
#    'x1': Decimal('289.848'),
#    'top': Decimal('376.563'),
#    'bottom': Decimal('398.326'),
#    'text': '16.0'},
#   {'x0': Decimal('306.562'),
#    'x1': Decimal('329.467'),
#    'top': Decimal('376.563'),
#    'bottom': Decimal('398.326'),
#    'text': '0/658'},
#   {'x0': Decimal('346.152'),
#    'x1': Decimal('363.754'),
#    'top': Decimal('376.563'),
#    'bottom': Decimal('398.326'),
#    'text': '52.7'},
#   {'x0': Decimal('383.108'),
#    'x1': Decimal('400.710'),
#    'top': Decimal('376.563'),
#    'bottom': Decimal('398.326'),
#    'text': '11.7'},
#   {'x0': Decimal('422.584'),
#    'x1': Decimal('435.157'),
#    'top': Decimal('376.563'),
#    'bottom': Decimal('398.326'),
#    'text': '0.0'},
#   {'x0': Decimal('454.381'),
#    'x1': Decimal('477.286'),
#    'top': Decimal('376.563'),
#    'bottom': Decimal('398.326'),
#    'text': '0/631'},
#   {'x0': Decimal('496.490'),
#    'x1': Decimal('509.063'),
#    'top': Decimal('376.563'),
#    'bottom': Decimal('398.326'),
#    'text': '3.7'},
#   {'x0': Decimal('530.927'),
#    'x1': Decimal('548.529'),
#    'top': Decimal('376.563'),
#    'bottom': Decimal('398.326'),
#    'text': '21.0'},
#   {'x0': Decimal('570.403'),
#    'x1': Decimal('582.976'),
#    'top': Decimal('376.563'),
#    'bottom': Decimal('398.326'),
#    'text': '0.0'},
#   {'x0': Decimal('602.199'),
#    'x1': Decimal('625.105'),
#    'top': Decimal('376.563'),
#    'bottom': Decimal('398.326'),
#    'text': '0/630'},
#   {'x0': Decimal('644.309'),
#    'x1': Decimal('656.882'),
#    'top': Decimal('376.563'),
#    'bottom': Decimal('398.326'),
#    'text': '3.4'},
#   {'x0': Decimal('676.226'),
#    'x1': Decimal('698.858'),
#    'top': Decimal('376.563'),
#    'bottom': Decimal('398.326'),
#    'text': '290.5'},
#   {'x0': Decimal('713.180'),
#    'x1': Decimal('735.812'),
#    'top': Decimal('376.563'),
#    'bottom': Decimal('398.326'),
#    'text': '123.4'},
#   {'x0': Decimal('750.015'),
#    'x1': Decimal('772.921'),
#    'top': Decimal('376.563'),
#    'bottom': Decimal('398.326'),
#    'text': '30/30'},
#   {'x0': Decimal('787.085'),
#    'x1': Decimal('809.716'),
#    'top': Decimal('376.563'),
#    'bottom': Decimal('398.326'),
#    'text': '205.8'}],
#  Decimal('421.606'): [{'x0': Decimal('30.593'),
#    'x1': Decimal('65.975'),
#    'top': Decimal('399.844'),
#    'bottom': Decimal('421.606'),
#    'text': 'ธันวาคม'},
#   {'x0': Decimal('87.473'),
#    'x1': Decimal('105.075'),
#    'top': Decimal('399.844'),
#    'bottom': Decimal('421.606'),
#    'text': '86.9'},
#   {'x0': Decimal('126.949'),
#    'x1': Decimal('139.522'),
#    'top': Decimal('399.844'),
#    'bottom': Decimal('421.606'),
#    'text': '6.4'},
#   {'x0': Decimal('158.746'),
#    'x1': Decimal('181.652'),
#    'top': Decimal('399.844'),
#    'bottom': Decimal('421.606'),
#    'text': '0/633'},
#   {'x0': Decimal('198.336'),
#    'x1': Decimal('215.939'),
#    'top': Decimal('399.844'),
#    'bottom': Decimal('421.606'),
#    'text': '30.8'},
#   {'x0': Decimal('232.773'),
#    'x1': Decimal('255.404'),
#    'top': Decimal('399.844'),
#    'bottom': Decimal('421.606'),
#    'text': '100.0'},
#   {'x0': Decimal('272.247'),
#    'x1': Decimal('289.850'),
#    'top': Decimal('399.844'),
#    'bottom': Decimal('421.606'),
#    'text': '22.0'},
#   {'x0': Decimal('306.563'),
#    'x1': Decimal('329.469'),
#    'top': Decimal('399.844'),
#    'bottom': Decimal('421.606'),
#    'text': '0/678'},
#   {'x0': Decimal('346.154'),
#    'x1': Decimal('363.756'),
#    'top': Decimal('399.844'),
#    'bottom': Decimal('421.606'),
#    'text': '61.5'},
#   {'x0': Decimal('383.109'),
#    'x1': Decimal('400.711'),
#    'top': Decimal('399.844'),
#    'bottom': Decimal('421.606'),
#    'text': '10.6'},
#   {'x0': Decimal('422.585'),
#    'x1': Decimal('435.158'),
#    'top': Decimal('399.844'),
#    'bottom': Decimal('421.606'),
#    'text': '0.0'},
#   {'x0': Decimal('454.382'),
#    'x1': Decimal('477.288'),
#    'top': Decimal('399.844'),
#    'bottom': Decimal('421.606'),
#    'text': '0/706'},
#   {'x0': Decimal('496.492'),
#    'x1': Decimal('509.065'),
#    'top': Decimal('399.844'),
#    'bottom': Decimal('421.606'),
#    'text': '3.6'},
#   {'x0': Decimal('530.928'),
#    'x1': Decimal('548.530'),
#    'top': Decimal('399.844'),
#    'bottom': Decimal('421.606'),
#    'text': '30.0'},
#   {'x0': Decimal('570.404'),
#    'x1': Decimal('582.977'),
#    'top': Decimal('399.844'),
#    'bottom': Decimal('421.606'),
#    'text': '0.0'},
#   {'x0': Decimal('602.201'),
#    'x1': Decimal('625.107'),
#    'top': Decimal('399.844'),
#    'bottom': Decimal('421.606'),
#    'text': '0/634'},
#   {'x0': Decimal('644.311'),
#    'x1': Decimal('656.884'),
#    'top': Decimal('399.844'),
#    'bottom': Decimal('421.606'),
#    'text': '4.8'},
#   {'x0': Decimal('676.228'),
#    'x1': Decimal('698.859'),
#    'top': Decimal('399.844'),
#    'bottom': Decimal('421.606'),
#    'text': '319.0'},
#   {'x0': Decimal('713.182'),
#    'x1': Decimal('735.813'),
#    'top': Decimal('399.844'),
#    'bottom': Decimal('421.606'),
#    'text': '137.8'},
#   {'x0': Decimal('750.017'),
#    'x1': Decimal('772.922'),
#    'top': Decimal('399.844'),
#    'bottom': Decimal('421.606'),
#    'text': '31/31'},
#   {'x0': Decimal('787.087'),
#    'x1': Decimal('809.718'),
#    'top': Decimal('399.844'),
#    'bottom': Decimal('421.606'),
#    'text': '224.7'}],
#  Decimal('452.207'): [{'x0': Decimal('23.153'),
#    'x1': Decimal('73.282'),
#    'top': Decimal('430.444'),
#    'bottom': Decimal('452.207'),
#    'text': 'ค่ามาตรฐาน'},
#   {'x0': Decimal('206.747'),
#    'x1': Decimal('210.100'),
#    'top': Decimal('430.444'),
#    'bottom': Decimal('452.207'),
#    'text': '-'},
#   {'x0': Decimal('354.591'),
#    'x1': Decimal('357.943'),
#    'top': Decimal('430.444'),
#    'bottom': Decimal('452.207'),
#    'text': '-'},
#   {'x0': Decimal('502.434'),
#    'x1': Decimal('505.787'),
#    'top': Decimal('430.444'),
#    'bottom': Decimal('452.207'),
#    'text': '-'},
#   {'x0': Decimal('650.277'),
#    'x1': Decimal('653.630'),
#    'top': Decimal('430.444'),
#    'bottom': Decimal('452.207'),
#    'text': '-'},
#   {'x0': Decimal('798.120'),
#    'x1': Decimal('801.473'),
#    'top': Decimal('430.444'),
#    'bottom': Decimal('452.207'),
#    'text': '-'}],
#  Decimal('451.362'): [{'x0': Decimal('125.751'),
#    'x1': Decimal('140.838'),
#    'top': Decimal('429.600'),
#    'bottom': Decimal('451.362'),
#    'text': '300'},
#   {'x0': Decimal('273.588'),
#    'x1': Decimal('288.675'),
#    'top': Decimal('429.600'),
#    'bottom': Decimal('451.362'),
#    'text': '170'},
#   {'x0': Decimal('423.944'),
#    'x1': Decimal('434.002'),
#    'top': Decimal('429.600'),
#    'bottom': Decimal('451.362'),
#    'text': '30'},
#   {'x0': Decimal('569.271'),
#    'x1': Decimal('584.358'),
#    'top': Decimal('429.600'),
#    'bottom': Decimal('451.362'),
#    'text': '100'},
#   {'x0': Decimal('717.102'),
#    'x1': Decimal('732.190'),
#    'top': Decimal('429.600'),
#    'bottom': Decimal('451.362'),
#    'text': '120'}],
#  Decimal('481.023'): [{'x0': Decimal('19.911'),
#    'x1': Decimal('53.996'),
#    'top': Decimal('463.028'),
#    'bottom': Decimal('481.023'),
#    'text': 'หมายเหตุ'},
#   {'x0': Decimal('60.529'),
#    'x1': Decimal('64.924'),
#    'top': Decimal('463.028'),
#    'bottom': Decimal('481.023'),
#    'text': '*'},
#   {'x0': Decimal('69.268'),
#    'x1': Decimal('71.705'),
#    'top': Decimal('463.028'),
#    'bottom': Decimal('481.023'),
#    'text': ':'},
#   {'x0': Decimal('75.951'),
#    'x1': Decimal('121.867'),
#    'top': Decimal('463.028'),
#    'bottom': Decimal('481.023'),
#    'text': 'ข\uf70bอมูลร\uf70bอยละ'},
#   {'x0': Decimal('124.046'),
#    'x1': Decimal('132.832'),
#    'top': Decimal('463.028'),
#    'bottom': Decimal('481.023'),
#    'text': '50'},
#   {'x0': Decimal('135.073'),
#    'x1': Decimal('138.003'),
#    'top': Decimal('463.028'),
#    'bottom': Decimal('481.023'),
#    'text': '-'},
#   {'x0': Decimal('140.134'),
#    'x1': Decimal('148.920'),
#    'top': Decimal('463.028'),
#    'bottom': Decimal('481.023'),
#    'text': '75'}],
#  Decimal('501.663'): [{'x0': Decimal('57.272'),
#    'x1': Decimal('66.063'),
#    'top': Decimal('483.667'),
#    'bottom': Decimal('501.663'),
#    'text': '**'},
#   {'x0': Decimal('70.459'),
#    'x1': Decimal('72.896'),
#    'top': Decimal('483.667'),
#    'bottom': Decimal('501.663'),
#    'text': ':'},
#   {'x0': Decimal('76.550'),
#    'x1': Decimal('152.227'),
#    'top': Decimal('483.667'),
#    'bottom': Decimal('501.663'),
#    'text': 'ข\uf70bอมูลน\uf70bอยกว่าร\uf70bอยละ'},
#   {'x0': Decimal('154.429'),
#    'x1': Decimal('163.211'),
#    'top': Decimal('483.667'),
#    'bottom': Decimal('501.663'),
#    'text': '50'},
#   {'x0': Decimal('685.911'),
#    'x1': Decimal('815.009'),
#    'top': Decimal('482.642'),
#    'bottom': Decimal('501.663'),
#    'text': 'สํานักจัดการคุณภาพอากาศและเสียง'}],
#  Decimal('522.302'): [{'x0': Decimal('61.667'),
#    'x1': Decimal('66.063'),
#    'top': Decimal('504.307'),
#    'bottom': Decimal('522.302'),
#    'text': '#'},
#   {'x0': Decimal('69.697'),
#    'x1': Decimal('72.134'),
#    'top': Decimal('504.307'),
#    'bottom': Decimal('522.302'),
#    'text': ':'},
#   {'x0': Decimal('76.429'),
#    'x1': Decimal('135.143'),
#    'top': Decimal('504.307'),
#    'bottom': Decimal('522.302'),
#    'text': 'ไม่มีการตรวจวัด'},
#   {'x0': Decimal('751.024'),
#    'x1': Decimal('755.420'),
#    'top': Decimal('503.281'),
#    'bottom': Decimal('522.302'),
#    'text': '3'},
#   {'x0': Decimal('761.868'),
#    'x1': Decimal('792.943'),
#    'top': Decimal('503.281'),
#    'bottom': Decimal('522.302'),
#    'text': 'สิงหาคม'},
#   {'x0': Decimal('797.266'),
#    'x1': Decimal('814.808'),
#    'top': Decimal('503.281'),
#    'bottom': Decimal('522.302'),
#    'text': '2546'}]}

# %%
def find_gas_line(word_by_line):
    for h, words in word_by_line.items():
        if words[0]['text'].startswith('ก๊าซ'):
            return h

def find_month_lines(word_by_line):
    tmp = {}
    for h, words in word_by_line.items():
        first_word = words[0]['text']
        if words[0]['text'] in months_set:
            tmp[first_word] = h
    return tmp

def find_year(word_by_line):
    first_line = min(word_by_line.keys())
    for word in word_by_line[first_line]:
        res = re.findall('25\d\d', word['text'])
        if res:
            return res[0]
            
    raise ValueError(f"Can't Find year {first_line}")

gas_line = find_gas_line(word_by_line)
month_lines = find_month_lines(word_by_line)
year = find_year(word_by_line)
assert(len(month_lines)==12)
print(year)
print(month_lines)
print(gas_lines)
def get_gas_names(line):
    tmp = []
    for iw, word in enumerate(line):
        if word['text'].startswith('ก๊าซ'):
            tmp.append(word['text'])
        elif word['text'].startswith('ฝุ่น'):
            tmp.append(word['text']+' '+line[iw+1]['text'])
    return tmp

def get_value(line):
    tmp = []
    for word in line[1:]: # first one is month
        tmp.append(word['text'])
    return tmp
    
gas_names = get_gas_names(word_by_line[gas_line])

all_data = []
for month_name, h in month_lines.items():
    values = get_value(line)
    assert(len(value) == 4*len(gas_names))
    for igas, gas_name in enumerate(gas_names):
        for icol, col_name in enumerate(col_map):
            ivalue = 4*igas + icol
            v = values[ivalue]
            this_data = {
                'year': year,
                'month': month_name,

            }
# Out:
# 2539
# {'มกราคม': Decimal('157.122'), 'กุมภาพันธ์': Decimal('181.243'), 'มีนาคม': Decimal('205.363'), 'เมษายน': Decimal('229.483'), 'พฤษภาคม': Decimal('253.604'), 'มิถุนายน': Decimal('277.724'), 'กรกฎาคม': Decimal('301.844'), 'สิงหาคม': Decimal('325.965'), 'กันยายน': Decimal('350.085'), 'ตุลาคม': Decimal('374.205'), 'พฤศจิกายน': Decimal('398.326'), 'ธันวาคม': Decimal('421.606')}
# 84.554
# ['ก๊าซซัลเฟอร์ไดออกไซด์',
#  'ก๊าซไนโตรเจนไดออกไซด์',
#  'ก๊าซโอโซน',
#  'ฝุ่นขนาดเล็กกว่า 10']

# %%
word_by_line[gas_line]
# Out:
# [{'x0': Decimal('98.751'),
#   'x1': Decimal('177.470'),
#   'top': Decimal('66.904'),
#   'bottom': Decimal('84.554'),
#   'text': 'ก๊าซซัลเฟอร์ไดออกไซด์'},
#  {'x0': Decimal('181.579'),
#   'x1': Decimal('184.298'),
#   'top': Decimal('66.904'),
#   'bottom': Decimal('84.554'),
#   'text': '('},
#  {'x0': Decimal('186.352'),
#   'x1': Decimal('197.229'),
#   'top': Decimal('66.904'),
#   'bottom': Decimal('84.554'),
#   'text': 'SO'},
#  {'x0': Decimal('202.070'),
#   'x1': Decimal('204.789'),
#   'top': Decimal('66.904'),
#   'bottom': Decimal('84.554'),
#   'text': ')'},
#  {'x0': Decimal('242.631'),
#   'x1': Decimal('327.950'),
#   'top': Decimal('66.904'),
#   'bottom': Decimal('84.554'),
#   'text': 'ก๊าซไนโตรเจนไดออกไซด์'},
#  {'x0': Decimal('332.059'),
#   'x1': Decimal('334.778'),
#   'top': Decimal('66.904'),
#   'bottom': Decimal('84.554'),
#   'text': '('},
#  {'x0': Decimal('336.832'),
#   'x1': Decimal('349.069'),
#   'top': Decimal('66.904'),
#   'bottom': Decimal('84.554'),
#   'text': 'NO'},
#  {'x0': Decimal('353.870'),
#   'x1': Decimal('356.589'),
#   'top': Decimal('66.904'),
#   'bottom': Decimal('84.554'),
#   'text': ')'},
#  {'x0': Decimal('565.791'),
#   'x1': Decimal('602.000'),
#   'top': Decimal('66.904'),
#   'bottom': Decimal('84.554'),
#   'text': 'ก๊าซโอโซน'},
#  {'x0': Decimal('606.138'),
#   'x1': Decimal('608.858'),
#   'top': Decimal('66.904'),
#   'bottom': Decimal('84.554'),
#   'text': '('},
#  {'x0': Decimal('610.912'),
#   'x1': Decimal('617.253'),
#   'top': Decimal('66.904'),
#   'bottom': Decimal('84.554'),
#   'text': 'O'},
#  {'x0': Decimal('622.070'),
#   'x1': Decimal('624.789'),
#   'top': Decimal('66.904'),
#   'bottom': Decimal('84.554'),
#   'text': ')'},
#  {'x0': Decimal('682.671'),
#   'x1': Decimal('736.929'),
#   'top': Decimal('66.904'),
#   'bottom': Decimal('84.554'),
#   'text': 'ฝุ่นขนาดเล็กกว่า'},
#  {'x0': Decimal('738.951'),
#   'x1': Decimal('747.108'),
#   'top': Decimal('66.904'),
#   'bottom': Decimal('84.554'),
#   'text': '10'},
#  {'x0': Decimal('749.151'),
#   'x1': Decimal('777.808'),
#   'top': Decimal('66.904'),
#   'bottom': Decimal('84.554'),
#   'text': 'ไมครอน'},
#  {'x0': Decimal('779.871'),
#   'x1': Decimal('795.301'),
#   'top': Decimal('66.904'),
#   'bottom': Decimal('84.554'),
#   'text': '(PM'},
#  {'x0': Decimal('800.871'),
#   'x1': Decimal('803.590'),
#   'top': Decimal('66.904'),
#   'bottom': Decimal('84.554'),
#   'text': ')'}]

# %%
im = my_pdf.pages[0].to_image(resolution=150)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-e81824b940f2> in <module>
# ----> 1 im = my_pdf.pages[0].to_image(resolution=150)
#
# NameError: name 'my_pdf' is not defined

# %%
import re

# %%
re.findall('25\d\d', 'ปี 2539')
# Out:
# ['2539']
